# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('seaborn-poster')
style.use('ggplot')
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(100)

drift = 100
r0 = np.random.randn(1000)

noise1 = np.random.normal(0, 0.4, 1000)
drift1 = 50
r1 = r0 + noise1
s1 = pd.Series(np.cumsum(r1), name='s1') + drift1


noise2 = np.random.normal(0, 0.4, 1000)
drift2 = 60
r2 = r0 + noise2
s2 = pd.Series(np.cumsum(r2), name='s2') + drift2

pd.concat([s1,s2], axis=1).plot(figsize=(15,6))

# %%
lr = LinearRegression()
lr.fit(s1.values.reshape(-1,1), s2.values.reshape(-1,1))
slope = lr.coef_[0][0]
intercept = lr.intercept_[0]
print('slope is: {}'.format(slope))
print('intercept is {}'.format(intercept))
# Out:
# slope is: 0.738851105982957
# intercept is 30.624444835631955

# %%
plt.scatter(s1.values, s2.values)
